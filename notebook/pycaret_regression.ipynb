# %% [markdown]
# # **REGRESSION**

# %% [markdown]
# # Pandas Profilling

# %%
# Load the dataset
from pycaret.datasets import get_data
house_prices = get_data('house', profile=True)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Setup

# %%
from pycaret.regression import *
# Initialize the setup
reg1 = setup(data=house_prices, target='SalePrice', session_id=123, experiment_name='Regression')
# Out:
# <style type="text/css">
# #T_fafa0_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fafa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fafa0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fafa0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fafa0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fafa0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fafa0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fafa0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fafa0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fafa0_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_fafa0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Compare Model

# %%
model_terbaik = compare_models(sort='MSE')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:40:13
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_e5ec7 th {
#   text-align: left;
# }
# ...

# %%
print(model_terbaik)

# %% [markdown]
# # Create Model

# %% [markdown]
# Note :
#
# Ini bertujuan untuk membuat model yang akan saya gunakan dalam melakukan training pada dataset saya

# %% [markdown]
# # Tune Model

# %%
cb = create_model('catboost')
tune_cb = tune_model(cb, n_iter=50, optimize='MSE', search_library='optuna', search_algorithm='random')
# Out:
# <style type="text/css">
# #T_3b8ab_row10_col0, #T_3b8ab_row10_col1, #T_3b8ab_row10_col2, #T_3b8ab_row10_col3, #T_3b8ab_row10_col4, #T_3b8ab_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3b8ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b8ab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3b8ab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3b8ab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3b8ab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3b8ab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3b8ab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# # Evaluate Model

# %%
plot_model(tune_cb)

# %%
plot_model(tune_cb, plot='feature')

# %% [markdown]
# # Interpret Model

# %%
interpret_model(tune_cb)

# %% [markdown]
# # Save Model

# %%
save_model(tune_cb, 'best_model_regression')

# %% [markdown]
# # Load Best Model

# %%
load_best = load_model('best_model_regression')
print(load_best)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Id', 'MSSubClass', 'LotFrontage',
#                                              'LotArea', 'OverallQual',
#                                              'OverallCond', 'YearBuilt',
#                                              'YearRemodAdd', 'MasVnrArea',
#                                              'BsmtFinSF1', 'BsmtFinSF2',
#                                              'BsmtUnfSF', 'TotalBsmtSF',
#                                              '1stFlrSF', '2ndFlrSF',
#                                              'LowQualFinSF', 'GrLivArea',
#                                              'BsmtFullBath', 'BsmtHalfBath',
#                                              'Ful...
#                                                                     'Exterior2nd',
# ...
